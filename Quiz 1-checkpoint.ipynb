# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = "ISO-8859-1")

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.describe(include="all").T
# Out:
#                 count unique                       top   freq         mean  \
# Area Code     60943.0    NaN                       NaN    NaN   134.265576
# Area            60943     49                     Kenya   1560          NaN
# Item Code     60943.0    NaN                       NaN    NaN  2687.176706
# Item            60943    119   Milk - Excluding Butter   1262          NaN
# Element Code  60943.0    NaN                       NaN    NaN  3814.856456
# Element         60943     18  Domestic supply quantity   5295          NaN
# Unit            60943      5               1000 tonnes  40933          NaN
# Y2014         59354.0    NaN                       NaN    NaN   134.196282
# Y2015         59395.0    NaN                       NaN    NaN   135.235966
# Y2016         59408.0    NaN                       NaN    NaN   136.555222
# Y2017         59437.0    NaN                       NaN    NaN   140.917765
# ...

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
dfu = df.loc[(df['Area'] == 'Madagascar') & (df['Element'] == 'Protein supply quantity (g/capita/day)')]

# %%
Total = dfu.groupby(['Y2015']).sum()
dfu.loc['Total'] = pd.Series(dfu['Y2015'].sum(), index=['Y2015'])
print(dfu)
# Out:
#        Area Code        Area  Item Code                      Item  \
# 30718      129.0  Madagascar     2901.0               Grand Total
# 30721      129.0  Madagascar     2903.0          Vegetal Products
# 30724      129.0  Madagascar     2941.0           Animal Products
# 30740      129.0  Madagascar     2905.0  Cereals - Excluding Beer
# 30756      129.0  Madagascar     2511.0        Wheat and products
# ...          ...         ...        ...                       ...
# 32123      129.0  Madagascar     2775.0            Aquatic Plants
# 32133      129.0  Madagascar     2928.0             Miscellaneous
# 32142      129.0  Madagascar     2680.0               Infant food
# 32152      129.0  Madagascar     2899.0             Miscellaneous
# Total        NaN         NaN        NaN                       NaN
#
#        Element Code                                 Element          Unit  \
# 30718         674.0  Protein supply quantity (g/capita/day)  g/capita/day
# ...

# %%
df1 = df[['Y2017', 'Area']]
df1
# Out:
#           Y2017      Area
# 0      41389.00   Algeria
# 1          0.00   Algeria
# 2       3341.00   Algeria
# 3         92.82   Algeria
# 4         80.19   Algeria
# ...         ...       ...
# 60939      1.33  Zimbabwe
# 60940      1.00  Zimbabwe
# 60941      0.04  Zimbabwe
# 60942      0.02  Zimbabwe
# Total       NaN       NaN
#
# [60944 rows x 2 columns]

# %%
# Out:
#   Cell In [38], line 1
#     df2= df1.groupby(['Area'])min()
#                               ^
# SyntaxError: invalid syntax

# %%
df1.groupby(['Area']).agg('max')
# Out:
#                                  Y2017
# Area
# Algeria                       41389.00
# Angola                        29817.00
# Benin                         11175.00
# Botswana                       2341.00
# Burkina Faso                  19193.00
# Cabo Verde                     2530.00
# Cameroon                      24566.00
# Central African Republic       4596.00
# Chad                          15017.00
# Comoros                          16.65
# Congo                          5111.00
# Côte d'Ivoire                 24437.00
# Djibouti                       2664.00
# Egypt                         96443.00
# Eswatini                       5553.00
# Ethiopia                     106400.00
# Ethiopia PDR                      0.00
# Gabon                          2640.00
# Gambia                         2544.00
# Ghana                         29121.00
# Guinea                        12068.00
# Guinea-Bissau                  2233.00
# Kenya                         50221.00
# ...

# %%
# Out:
# 'e'

# %%
df.nunique()
# Out:
# Area Code         49
# Area              49
# Item Code        122
# Item             119
# Element Code      18
# Element           18
# Unit               5
# Y2014           4493
# Y2015           4521
# Y2016           4520
# Y2017           4537
# Y2018           4591
# dtype: int64

# %%
df.groupby(['Element']).agg('max')
# Out:
#                                         Area Code                   Area  \
# Element
# Domestic supply quantity                    276.0               Zimbabwe
# Export Quantity                             276.0               Zimbabwe
# Fat supply quantity (g/capita/day)          276.0               Zimbabwe
# Feed                                        276.0               Zimbabwe
# Food                                        276.0               Zimbabwe
# Food supply (kcal/capita/day)               276.0               Zimbabwe
# Food supply quantity (kg/capita/yr)         276.0               Zimbabwe
# Import Quantity                             276.0               Zimbabwe
# Losses                                      276.0               Zimbabwe
# Other uses (non-food)                       276.0               Zimbabwe
# Processing                                  276.0               Zimbabwe
# Production                                  276.0               Zimbabwe
# ...

# %%
df.groupby(['Item']).sum()
# Out:
# C:\Users\CLASS\AppData\Local\Temp\ipykernel_216\1701463969.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Item']).sum()
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food      38447.0   752497.0     1515090.0    2403.00    2180.00
# Alcoholic Beverages    75016.0  1649136.0     2171381.0  102410.11   98783.72
# Animal Products        18060.0   397035.0       90990.0   11935.65   11811.73
# Animal fats            85279.0  1882494.0     2567303.0  209460.54  200675.72
# Apples and products    69280.0  1352989.0     1920418.0    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other      77779.0  1518715.0     2275409.0  155038.96  158104.08
# ...

# %%
df.groupby(['Element']).sum()
# Out:
# C:\Users\CLASS\AppData\Local\Temp\ipykernel_216\2707822162.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Element']).sum()
#                                         Area Code   Item Code  Element Code  \
# Element
# Domestic supply quantity                 708993.0  14197445.0    28068795.0
# Export Quantity                          599910.0  11840553.0    26026133.0
# Fat supply quantity (g/capita/day)       675050.0  13535000.0     3435732.0
# Feed                                     176272.0   3538507.0     7282199.0
# Food                                     663295.0  13285035.0    25406622.0
# Food supply (kcal/capita/day)            674057.0  13511060.0     3329296.0
# Food supply quantity (kg/capita/yr)      658446.0  13185401.0     3163725.0
# ...

# %%
df.sum
